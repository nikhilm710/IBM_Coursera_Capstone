# %% [markdown]
# ## Creating the dataframe for neighbourshood in Toronto

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/ibm/conda/miniconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     openssl-1.0.2p             |       h470a237_1         3.1 MB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     conda-4.5.11               |           py35_0         636 KB  conda-forge
#     ca-certificates-2018.8.24  |       ha4d7672_0         136 KB  conda-forge
#     geopy-1.17.0               |             py_0          49 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# using BeautifulSoup package to scrap the wiki data
from bs4 import BeautifulSoup

# %%
url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
wiki_data = BeautifulSoup(url.text,'lxml')

# %%
import csv
csv_wiki = open('canadadata.csv','w')
csv_writer = csv.writer(csv_wiki)
csv_writer.writerow(['PostalCode', 'Borough','Neighborhood'])
for tr in wiki_data.find_all('tr')[1:]:
    tds = tr.find_all('td')
    if len(tds)==3:
        PostalCode=tds[0].text
        Borough=tds[1].text
        Neighbourhood=tds[2].text
    
    csv_writer.writerow([PostalCode, Borough, Neighbourhood])
csv_wiki.close()

# %%
import pandas as pd
df_canada=pd.read_csv('canadadata.csv')

# %%
df_canada.head()
# Out:
#   PostalCode           Borough        Neighborhood
# 0        M1A      Not assigned      Not assigned\n
# 1        M2A      Not assigned      Not assigned\n
# 2        M3A        North York         Parkwoods\n
# 3        M4A        North York  Victoria Village\n
# 4        M5A  Downtown Toronto      Harbourfront\n

# %% [markdown]
# ## Ignore cells with a borough that is Not assigned

# %%
df_canada[df_canada.columns] = df_canada.apply(lambda x: x.str.strip('\n'))
df_canada.head()
df_canada.shape
# Out:
# (294, 3)

# %%
df_canada=df_canada[df_canada.Borough!='Not assigned']
df_canada.head()
df_canada.shape
# Out:
# (212, 3)

# %%
df_canada.set_index(['PostalCode','Borough'],inplace=True)
df_canada = df_canada.groupby(level=['PostalCode','Borough'], sort=False).agg( ','.join)

# %%
df_canada.shape
df_canada.reset_index()
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# ...

# %%
df_canada.reset_index()
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# ...

# %% [markdown]
# ## Making the neighborhood will be the same as the borough for cell has a borough but a Not assigned neighborhood

# %%
df_canada.loc[df_canada['Neighborhood'] =='Not assigned']=df_canada[df_canada['Neighborhood'] == 'Not assigned'].index.values[0][1]
df_canada.head()
# Out:
#                                                 Neighborhood
# PostalCode Borough
# M3A        North York                              Parkwoods
# M4A        North York                       Victoria Village
# M5A        Downtown Toronto         Harbourfront,Regent Park
# M6A        North York        Lawrence Heights,Lawrence Manor
# M7A        Queen's Park                         Queen's Park

# %%
df_canada.reset_index(inplace=True)

# %%
df_canada
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# ...

# %%
df_canada.shape
# Out:
# (103, 3)

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_geo_cord = df_data_1

# %%
df_canada_cord = pd.merge(df_canada,df_geo_cord, how='inner', left_on = 'PostalCode', right_on = 'Postal Code')

# %%
df_canada_cord.head()
# Out:
#   PostalCode           Borough                     Neighborhood Postal Code  \
# 0        M3A        North York                        Parkwoods         M3A
# 1        M4A        North York                 Victoria Village         M4A
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park         M5A
# 3        M6A        North York  Lawrence Heights,Lawrence Manor         M6A
# 4        M7A      Queen's Park                     Queen's Park         M7A
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
df_canada_cord.drop(columns='Postal Code',inplace=True)

# %%
df_canada_cord
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# ...
